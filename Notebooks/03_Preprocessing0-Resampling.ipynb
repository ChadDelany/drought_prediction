# %% [markdown]
# # Drought Prediction: Preprocessing - Resampling

# %% [markdown]
# INSERT EXPLANATORY TEXT

# %%
#Import pandas, matplotlib.pyplot, and seaborn
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Load Merged Soil & Meteorological Dataset

# %%
# Local location of the data
# local_data = 'D:\\Data_Science\\DroughtProject\\Data\\' # Location on Windows
local_data = '/home/chad/Data/Drought_Prediction/' # Location on Linux

# Load the first half of the scaled & merged dataset of meteorological and soil variables.
ts_merge0_scaled = pd.read_csv(local_data + 'ts_merge0_scaled.csv', 
                        parse_dates=['date'], 
                        index_col=['fips'],
                        header=0)

# %%
ts_merge0_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9650341 entries, 1001 to 56043
# Data columns (total 51 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           datetime64[ns]
#  1   PRECTOT        float64
#  2   PS             float64
#  3   QV2M           float64
#  4   T2M            float64
#  5   T2MDEW         float64
#  6   T2MWET         float64
#  7   T2M_MAX        float64
#  8   T2M_MIN        float64
#  9   T2M_RANGE      float64
#  10  TS             float64
#  11  WS10M          float64
#  12  WS10M_MAX      float64
#  13  WS10M_MIN      float64
#  14  WS10M_RANGE    float64
#  15  WS50M          float64
#  16  WS50M_MAX      float64
#  17  WS50M_MIN      float64
#  18  WS50M_RANGE    float64
#  19  lat            float64
#  20  lon            float64
#  21  elevation      float64
#  22  slope1         float64
#  23  slope2         float64
#  24  slope3         float64
#  25  slope4         float64
#  26  slope5         float64
# ...

# %%
ts_merge0_scaled.head()
# Out:
#            date   PRECTOT        PS      QV2M       T2M    T2MDEW    T2MWET  \
# fips
# 1001 2000-01-01 -0.396480  0.552630  0.302636  0.138316  0.563310  0.562943
# 1001 2000-01-02 -0.399523  0.559985  0.460871  0.317114  0.680164  0.680374
# 1001 2000-01-03  0.125260  0.486436  0.736241  0.482159  0.856419  0.857500
# 1001 2000-01-04  1.996223  0.512178 -0.361130 -0.167934 -0.159238 -0.162196
# 1001 2000-01-05 -0.429945  0.670308 -1.074217 -0.859288 -1.072647 -1.072290
#
#        T2M_MAX   T2M_MIN  T2M_RANGE  ...  CULTIR_LAND  CULT_LAND       SQ1  \
# fips                                 ...
# 1001  0.168457  0.335466  -0.417993  ...    -0.266678   0.515974 -0.707612
# 1001  0.329331  0.443382  -0.245534  ...    -0.266678   0.515974 -0.707612
# 1001  0.323211  0.697688  -0.948050  ...    -0.266678   0.515974 -0.707612
# 1001 -0.082471 -0.537246   1.210220  ...    -0.266678   0.515974 -0.707612
# 1001 -0.718098 -0.989554   0.591398  ...    -0.266678   0.515974 -0.707612
#
# ...

# %%
ts_merge0_scaled.resample('W', on='date', origin='2000-01-04').mean()
# Out:
#              PRECTOT        PS      QV2M       T2M    T2MDEW    T2MWET  \
# date
# 2000-01-02 -0.142796 -0.038440 -0.392317 -0.565233 -0.268366 -0.271269
# 2000-01-09 -0.012129  0.045248 -0.791096 -0.955056 -0.835259 -0.835682
# 2000-01-16 -0.230158  0.089874 -0.831149 -0.893789 -0.874141 -0.873642
# 2000-01-23 -0.129625  0.027745 -0.912849 -1.179527 -1.075162 -1.073806
# 2000-01-30 -0.111458  0.114686 -1.159523 -1.551879 -1.439819 -1.439846
# ...              ...       ...       ...       ...       ...       ...
# 2016-12-04  0.337282 -0.069510 -0.610781 -0.639872 -0.539972 -0.542487
# 2016-12-11  0.089568  0.069296 -0.899014 -1.106987 -1.017726 -1.015996
# 2016-12-18  0.027297  0.044756 -0.853009 -1.276078 -1.154557 -1.145461
# 2016-12-25 -0.158055  0.111724 -0.752382 -1.007876 -0.788010 -0.789250
# 2017-01-01 -0.100521  0.020583 -0.687336 -0.813489 -0.722142 -0.723828
#
#              T2M_MAX   T2M_MIN  T2M_RANGE        TS  ...   CULTIR_LAND  \
# ...

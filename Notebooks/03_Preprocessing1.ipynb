# %% [markdown]
# # Drought Prediction: Preprocessing & Training Data Development

# %% [markdown]
# INSERT EXPLANATORY TEXT

# %%
#Import pandas, matplotlib.pyplot, and seaborn
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Load Merged Soil & Meteorological Dataset

# %%
# Local location of the data
# local_data = 'D:\\Data_Science\\DroughtProject\\Data\\' # Location on Windows
local_data = '/home/chad/Data/Drought_Prediction/' # Location on Linux

# Load the merged dataset of training and soil variables.
# ts_merge = pd.read_csv(local_data + 'train_soil_merge.csv') # Run out of RAM (32GB), file size - 6.8GB

N = 19300680 # number of rows in the training_data_set & the merge.
N1 = int(N/2)

ts_merge1 = pd.read_csv(local_data + 'train_soil_merge.csv', 
                        skiprows=[i for i in range(1,N1)], 
                        parse_dates=['date'], 
                        index_col=['fips'],
                        header=0)

# %%
ts_merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9650341 entries, 29211 to 56043
# Data columns (total 52 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Unnamed: 0     int64
#  1   date           datetime64[ns]
#  2   PRECTOT        float64
#  3   PS             float64
#  4   QV2M           float64
#  5   T2M            float64
#  6   T2MDEW         float64
#  7   T2MWET         float64
#  8   T2M_MAX        float64
#  9   T2M_MIN        float64
#  10  T2M_RANGE      float64
#  11  TS             float64
#  12  WS10M          float64
#  13  WS10M_MAX      float64
#  14  WS10M_MIN      float64
#  15  WS10M_RANGE    float64
#  16  WS50M          float64
#  17  WS50M_MAX      float64
#  18  WS50M_MIN      float64
#  19  WS50M_RANGE    float64
#  20  score          float64
#  21  lat            float64
#  22  lon            float64
#  23  elevation      int64
#  24  slope1         float64
#  25  slope2         float64
#  26  slope3         float64
# ...

# %%
ts_merge1.head()
# Out:
#        Unnamed: 0       date  PRECTOT     PS  QV2M    T2M  T2MDEW  T2MWET  \
# fips
# 29211     9650339 2016-12-31     0.00  97.70  2.68  -0.44   -5.01   -4.94
# 29213     9650340 2000-01-01     0.01  97.05  5.35   7.22    3.93    3.94
# 29213     9650341 2000-01-02     2.74  96.71  7.75  10.91    9.50    9.50
# 29213     9650342 2000-01-03    21.43  96.40  5.96   6.87    5.29    5.29
# 29213     9650343 2000-01-04     0.17  98.00  2.24  -3.21   -7.34   -7.21
#
#        T2M_MAX  T2M_MIN  ...  CULTRF_LAND  CULTIR_LAND  CULT_LAND  SQ1  SQ2  \
# fips                     ...
# 29211     2.94    -4.10  ...    82.339706     1.864281  84.203987    1    1
# 29213    15.90    -0.38  ...     0.000000     0.000000   0.000000    2    2
# 29213    14.41     5.70  ...     0.000000     0.000000   0.000000    2    2
# 29213    13.47     0.79  ...     0.000000     0.000000   0.000000    2    2
# 29213     0.21    -6.08  ...     0.000000     0.000000   0.000000    2    2
#
# ...

# %%
ts_merge1 = ts_merge1.drop('Unnamed: 0', axis=1)

# %%
ts_merge1
# Out:
#             date  PRECTOT     PS  QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# fips
# 29211 2016-12-31     0.00  97.70  2.68  -0.44   -5.01   -4.94     2.94
# 29213 2000-01-01     0.01  97.05  5.35   7.22    3.93    3.94    15.90
# 29213 2000-01-02     2.74  96.71  7.75  10.91    9.50    9.50    14.41
# 29213 2000-01-03    21.43  96.40  5.96   6.87    5.29    5.29    13.47
# 29213 2000-01-04     0.17  98.00  2.24  -3.21   -7.34   -7.21     0.21
# ...          ...      ...    ...   ...    ...     ...     ...      ...
# 56043 2016-12-27     0.16  82.88  1.63  -7.97  -13.49  -12.81    -1.39
# 56043 2016-12-28     0.02  83.33  1.41  -8.71  -14.10  -13.84    -2.49
# 56043 2016-12-29     0.00  83.75  1.59  -7.96  -13.30  -13.03     0.42
# 56043 2016-12-30     1.22  82.49  2.63  -2.94   -7.40   -7.33     3.76
# 56043 2016-12-31     0.44  82.19  1.75  -7.56  -11.98  -11.82    -0.95
#
#        T2M_MIN  T2M_RANGE  ...  CULTRF_LAND  CULTIR_LAND  CULT_LAND  SQ1  SQ2  \
# ...

# %%
ts_merge1.columns
# Out:
# Index(['date', 'PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX',
#        'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX', 'WS10M_MIN',
#        'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN', 'WS50M_RANGE',
#        'score', 'lat', 'lon', 'elevation', 'slope1', 'slope2', 'slope3',
#        'slope4', 'slope5', 'slope6', 'slope7', 'slope8', 'aspectN', 'aspectE',
#        'aspectS', 'aspectW', 'aspectUnknown', 'WAT_LAND', 'NVG_LAND',
#        'URB_LAND', 'GRS_LAND', 'FOR_LAND', 'CULTRF_LAND', 'CULTIR_LAND',
#        'CULT_LAND', 'SQ1', 'SQ2', 'SQ3', 'SQ4', 'SQ5', 'SQ6', 'SQ7'],
#       dtype='object')

# %%
features = ['PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW',
       'T2MWET', 'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX',
       'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN',
       'WS50M_RANGE', 'lat', 'lon', 'elevation', 'slope1', 'slope2',
       'slope3', 'slope4', 'slope5', 'slope6', 'slope7', 'slope8', 'aspectN',
       'aspectE', 'aspectS', 'aspectW', 'aspectUnknown', 'WAT_LAND',
       'NVG_LAND', 'URB_LAND', 'GRS_LAND', 'FOR_LAND', 'CULTRF_LAND',
       'CULTIR_LAND', 'CULT_LAND', 'SQ1', 'SQ2', 'SQ3', 'SQ4', 'SQ5', 'SQ6',
       'SQ7']

# Separating out the features
X1 = ts_merge1.loc[:, features].values

# Separating out the target
y1 = ts_merge1.loc[:,['score']].values

# Standardizing the features
X1 = StandardScaler().fit_transform(X1)

# %%
X1
# Out:
# array([[-0.42065982,  0.35555785, -1.06420994, ..., -0.16575452,
#         -0.14863635, -0.31448701],
#        [-0.41895105,  0.23346403, -0.46914794, ..., -0.16575452,
#         -0.14863635, -0.31448701],
#        [ 0.04754389,  0.16959957,  0.06573924, ..., -0.16575452,
#         -0.14863635, -0.31448701],
#        ...,
#        [-0.42065982, -2.26476344, -1.30713787, ..., -0.16575452,
#         -0.14863635, -0.31448701],
#        [-0.21218955, -2.50143762, -1.07535342, ..., -0.16575452,
#         -0.14863635, -0.31448701],
#        [-0.34547382, -2.55778862, -1.27147872, ..., -0.16575452,
#         -0.14863635, -0.31448701]])

# %%
date1 = ts_merge1['date']

# %%
date1
# Out:
# fips
# 29211   2016-12-31
# 29213   2000-01-01
# 29213   2000-01-02
# 29213   2000-01-03
# 29213   2000-01-04
#            ...
# 56043   2016-12-27
# 56043   2016-12-28
# 56043   2016-12-29
# 56043   2016-12-30
# 56043   2016-12-31
# Name: date, Length: 9650341, dtype: datetime64[ns]

# %%
date1_df = pd.DataFrame(date1, index=ts_merge1.index, columns=['date'])

# %%
date1_df
# Out:
#             date
# fips
# 29211 2016-12-31
# 29213 2000-01-01
# 29213 2000-01-02
# 29213 2000-01-03
# 29213 2000-01-04
# ...          ...
# 56043 2016-12-27
# 56043 2016-12-28
# 56043 2016-12-29
# 56043 2016-12-30
# 56043 2016-12-31
#
# [9650341 rows x 1 columns]

# %%
y1
# Out:
# array([[nan],
#        [nan],
#        [nan],
#        ...,
#        [nan],
#        [nan],
#        [nan]])

# %%
y1_df = pd.DataFrame(y1, index=ts_merge1.index, columns=['score'])

# %%
y1_df
# Out:
#        score
# fips
# 29211    NaN
# 29213    NaN
# 29213    NaN
# 29213    NaN
# 29213    0.0
# ...      ...
# 56043    0.0
# 56043    NaN
# 56043    NaN
# 56043    NaN
# 56043    NaN
#
# [9650341 rows x 1 columns]

# %%
X1_df = pd.DataFrame(X1, index=ts_merge1.index, columns=features)

# %%
X1_df
# Out:
#         PRECTOT        PS      QV2M       T2M    T2MDEW    T2MWET   T2M_MAX  \
# fips
# 29211 -0.420660  0.355558 -1.064210 -1.172088 -1.123151 -1.126660 -1.322059
# 29213 -0.418951  0.233464 -0.469148 -0.471290 -0.225585 -0.229887 -0.208713
# 29213  0.047544  0.169600  0.065739 -0.133700  0.333636  0.331605 -0.336714
# 29213  3.241240  0.111370 -0.333197 -0.503311 -0.089043 -0.093554 -0.417466
# 29213 -0.391611  0.411909 -1.162273 -1.425510 -1.357080 -1.355902 -1.556583
# ...         ...       ...       ...       ...       ...       ...       ...
# 56043 -0.393319 -2.428181 -1.298223 -1.860992 -1.974533 -1.921434 -1.694033
# 56043 -0.417242 -2.343655 -1.347254 -1.928693 -2.035776 -2.025452 -1.788530
# 56043 -0.420660 -2.264763 -1.307138 -1.860077 -1.955457 -1.943652 -1.538542
# 56043 -0.212190 -2.501438 -1.075353 -1.400808 -1.363104 -1.368021 -1.251615
# 56043 -0.345474 -2.557789 -1.271479 -1.823482 -1.822930 -1.821456 -1.656234
#
# ...

# %%
X1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9650341 entries, 29211 to 56043
# Data columns (total 49 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   PRECTOT        float64
#  1   PS             float64
#  2   QV2M           float64
#  3   T2M            float64
#  4   T2MDEW         float64
#  5   T2MWET         float64
#  6   T2M_MAX        float64
#  7   T2M_MIN        float64
#  8   T2M_RANGE      float64
#  9   TS             float64
#  10  WS10M          float64
#  11  WS10M_MAX      float64
#  12  WS10M_MIN      float64
#  13  WS10M_RANGE    float64
#  14  WS50M          float64
#  15  WS50M_MAX      float64
#  16  WS50M_MIN      float64
#  17  WS50M_RANGE    float64
#  18  lat            float64
#  19  lon            float64
#  20  elevation      float64
#  21  slope1         float64
#  22  slope2         float64
#  23  slope3         float64
#  24  slope4         float64
#  25  slope5         float64
#  26  slope6         float64
# ...

# %%
# ts_merge0_scaled = pd.merge(date0_df, X0_df, left_index=True, right_index=True) # Memory Error: Unalbe to allocate 447GB
# ts_merge0_scaled = date0_df.join(X0_df) # Memory Error: Unalbe to allocate 447GB
ts_merge1_scaled = pd.concat([date1_df, X1_df], axis=1)

# %%
ts_merge1_scaled
# Out:
#             date   PRECTOT        PS      QV2M       T2M    T2MDEW    T2MWET  \
# fips
# 29211 2016-12-31 -0.420660  0.355558 -1.064210 -1.172088 -1.123151 -1.126660
# 29213 2000-01-01 -0.418951  0.233464 -0.469148 -0.471290 -0.225585 -0.229887
# 29213 2000-01-02  0.047544  0.169600  0.065739 -0.133700  0.333636  0.331605
# 29213 2000-01-03  3.241240  0.111370 -0.333197 -0.503311 -0.089043 -0.093554
# 29213 2000-01-04 -0.391611  0.411909 -1.162273 -1.425510 -1.357080 -1.355902
# ...          ...       ...       ...       ...       ...       ...       ...
# 56043 2016-12-27 -0.393319 -2.428181 -1.298223 -1.860992 -1.974533 -1.921434
# 56043 2016-12-28 -0.417242 -2.343655 -1.347254 -1.928693 -2.035776 -2.025452
# 56043 2016-12-29 -0.420660 -2.264763 -1.307138 -1.860077 -1.955457 -1.943652
# 56043 2016-12-30 -0.212190 -2.501438 -1.075353 -1.400808 -1.363104 -1.368021
# 56043 2016-12-31 -0.345474 -2.557789 -1.271479 -1.823482 -1.822930 -1.821456
#
# ...

# %%
ts_merge1_scaled = pd.concat([ts_merge1_scaled, y1_df], axis=1)

# %%
ts_merge1_scaled
# Out:
#             date   PRECTOT        PS      QV2M       T2M    T2MDEW    T2MWET  \
# fips
# 29211 2016-12-31 -0.420660  0.355558 -1.064210 -1.172088 -1.123151 -1.126660
# 29213 2000-01-01 -0.418951  0.233464 -0.469148 -0.471290 -0.225585 -0.229887
# 29213 2000-01-02  0.047544  0.169600  0.065739 -0.133700  0.333636  0.331605
# 29213 2000-01-03  3.241240  0.111370 -0.333197 -0.503311 -0.089043 -0.093554
# 29213 2000-01-04 -0.391611  0.411909 -1.162273 -1.425510 -1.357080 -1.355902
# ...          ...       ...       ...       ...       ...       ...       ...
# 56043 2016-12-27 -0.393319 -2.428181 -1.298223 -1.860992 -1.974533 -1.921434
# 56043 2016-12-28 -0.417242 -2.343655 -1.347254 -1.928693 -2.035776 -2.025452
# 56043 2016-12-29 -0.420660 -2.264763 -1.307138 -1.860077 -1.955457 -1.943652
# 56043 2016-12-30 -0.212190 -2.501438 -1.075353 -1.400808 -1.363104 -1.368021
# 56043 2016-12-31 -0.345474 -2.557789 -1.271479 -1.823482 -1.822930 -1.821456
#
# ...

# %%
ts_merge1_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9650341 entries, 29211 to 56043
# Data columns (total 51 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           datetime64[ns]
#  1   PRECTOT        float64
#  2   PS             float64
#  3   QV2M           float64
#  4   T2M            float64
#  5   T2MDEW         float64
#  6   T2MWET         float64
#  7   T2M_MAX        float64
#  8   T2M_MIN        float64
#  9   T2M_RANGE      float64
#  10  TS             float64
#  11  WS10M          float64
#  12  WS10M_MAX      float64
#  13  WS10M_MIN      float64
#  14  WS10M_RANGE    float64
#  15  WS50M          float64
#  16  WS50M_MAX      float64
#  17  WS50M_MIN      float64
#  18  WS50M_RANGE    float64
#  19  lat            float64
#  20  lon            float64
#  21  elevation      float64
#  22  slope1         float64
#  23  slope2         float64
#  24  slope3         float64
#  25  slope4         float64
#  26  slope5         float64
# ...

# %%
ts_merge1_scaled.to_csv(local_data + 'ts_merge1_scaled.csv')
